# %% [markdown]
# # **Superstore EDA**

# %% [markdown]
# ## **Phase 1 - Data Understanding**

# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown, display
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Superstore.csv",encoding='ISO-8859-1')
# pd.set_option("display.max_columns",None)

# %%
import os
os.listdir("/content")
# Out:
# ['.config', 'drive', 'sample_data']

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.memory_usage(deep=True).sum() / (1024**2)
# Out:
# np.float64(9.206507682800293)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3193    3194  CA-2014-165428    9/1/2014    9/4/2014     First Class
# 5248    5249  US-2017-110989   11/3/2017   11/5/2017    Second Class
# 7431    7432  US-2014-164763   3/17/2014   3/21/2014  Standard Class
# 8794    8795  CA-2014-162992  12/19/2014  12/21/2014     First Class
# 6962    6963  CA-2016-157161   7/16/2016   7/20/2016    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 3193    JL-15130       Jack Lebron   Consumer  United States      Houston
# 5248    EJ-14155        Eva Jacobs   Consumer  United States      Seattle
# 7431    MH-17440     Mark Haberlin  Corporate  United States      Jackson
# 8794    BP-11095      Bart Pistole  Corporate  United States  Los Angeles
# 6962    JD-15895  Jonathan Doherty  Corporate  United States     Columbia
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#         Row ID  Postal Code     Sales  Quantity  Discount    Profit
# count 9,994.00     9,994.00  9,994.00  9,994.00  9,994.00  9,994.00
# mean  4,997.50    55,190.38    229.86      3.79      0.16     28.66
# std   2,885.16    32,063.69    623.25      2.23      0.21    234.26
# min       1.00     1,040.00      0.44      1.00      0.00 -6,599.98
# 25%   2,499.25    23,223.00     17.28      2.00      0.00      1.73
# 50%   4,997.50    56,430.50     54.49      3.00      0.20      8.67
# 75%   7,495.75    90,008.00    209.94      5.00      0.20     29.36
# max   9,994.00    99,301.00 22,638.48     14.00      0.80  8,399.98

# %%
df.describe(include="object")
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994       9994        9994            9994        9994
# unique            5009       1237        1334               4         793
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class    WB-21850
# freq                14         38          35            5968          37
#
#         Customer Name   Segment        Country           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
#
#        Region       Product ID         Category Sub-Category     Product Name
# count    9994             9994             9994         9994             9994
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
df_cols= ["Ship Mode","Customer Name","Segment","Country","City","State","Region","Category","Sub-Category","Product Name"]
for col in df_cols:
    display(Markdown(f"## {col}"))
    display(df[col].value_counts().head(10))
    print(f"Unique values: {df[col].nunique()}")
# Out:
# ## Ship Mode
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64
# Unique values: 4
# ## Customer Name
# Customer Name
# William Brown          37
# Matt Abelman           34
# John Lee               34
# Paul Prost             34
# Chloris Kastensmidt    32
# Jonathan Doherty       32
# Edward Hooks           32
# Seth Vernon            32
# Zuschuss Carroll       31
# Emily Phan             31
# Name: count, dtype: int64
# Unique values: 793
# ## Segment
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64
# Unique values: 3
# ## Country
# Country
# United States    9994
# Name: count, dtype: int64
# Unique values: 1
# ## City
# City
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# ...

# %% [markdown]
# ### **Observations**
#
# - The dataset contains **9,994 rows** and **21 columns**.
# - The ID columns are **Row ID, Order ID, Customer ID, and Product ID**.
# - **Order Date** and **Ship Date** should be converted to the **datetime** data type for easier date-based analysis.
# - The main categorical columns are **Segment, State, Region, Category, Sub-Category, and Ship Mode**.
# - The main numerical columns are **Sales, Quantity, Profit, and Discount**.
# - No duplicate rows or missing values were found in the dataset.
# - The dataset uses approximately **9.2 MB** of memory.
# - Overall, the dataset contains transactional sales information, including customer, product, shipping, sales, discount, and profit details.

# %% [markdown]
# ## **Phase 2 – Data Quality Assessment**

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.isna().mean()*100
# Out:
# Row ID          0.00
# Order ID        0.00
# Order Date      0.00
# Ship Date       0.00
# Ship Mode       0.00
# Customer ID     0.00
# Customer Name   0.00
# Segment         0.00
# Country         0.00
# City            0.00
# State           0.00
# Postal Code     0.00
# Region          0.00
# Product ID      0.00
# Category        0.00
# Sub-Category    0.00
# Product Name    0.00
# Sales           0.00
# Quantity        0.00
# Discount        0.00
# Profit          0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Discount"].describe()
# Out:
# count   9,994.00
# mean        0.16
# std         0.21
# min         0.00
# 25%         0.00
# 50%         0.20
# 75%         0.20
# max         0.80
# Name: Discount, dtype: float64

# %%
df["Discount"].unique()
# Out:
# array([0.  , 0.45, 0.2 , 0.8 , 0.3 , 0.5 , 0.7 , 0.6 , 0.32, 0.1 , 0.4 ,
#        0.15])

# %%
(df["Profit"] < 0).sum()
# Out:
# np.int64(1871)

# %%
round((df["Profit"] < 0).mean() * 100,2)
# Out:
# np.float64(18.72)

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df['Postal Code']=df['Postal Code'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   object
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe(include="all")
# Out:
#          Row ID        Order ID                     Order Date  \
# count  9,994.00            9994                           9994
# unique      NaN            5009                            NaN
# top         NaN  CA-2017-100111                            NaN
# freq        NaN              14                            NaN
# mean   4,997.50             NaN  2016-04-30 00:07:12.259355648
# min        1.00             NaN            2014-01-03 00:00:00
# 25%    2,499.25             NaN            2015-05-23 00:00:00
# 50%    4,997.50             NaN            2016-06-26 00:00:00
# 75%    7,495.75             NaN            2017-05-14 00:00:00
# max    9,994.00             NaN            2017-12-30 00:00:00
# std    2,885.16             NaN                            NaN
#
#                             Ship Date       Ship Mode Customer ID  \
# count                            9994            9994        9994
# unique                            NaN               4         793
# ...

# %% [markdown]
# ### **Observations**
#
# - No missing values were found in the dataset.
# - No duplicate rows were detected.
# - The categorical columns contain consistent labels with no spelling mistakes or unexpected categories.
# - The numerical columns contain valid business values with no obvious anomalies.
# - **Order Date** and **Ship Date** were converted from string to **datetime** format.
# - **Postal Code** was converted from integer to string since it is an identifier and not used for numerical calculations.
# - Approximately **18.72% of the transactions resulted in a loss**, which appears to be a business issue rather than a data quality problem.

# %% [markdown]
# ## **Phase 3 – Univariate Analysis**

# %% [markdown]
# ### **Part A - Numerical Features**

# %%
num_cols=["Sales","Profit","Quantity","Discount"]

# %%
#mean, median, mode, kurtosis, skewness

df[num_cols].agg(["mean","median",
                  lambda x:
                  x.mode().iloc[0] if not x.mode().empty else None,"kurt","skew"]
                 ).rename(index={"<lambda>":"mode"}
        ).T
# Out:
#            mean  median  mode   kurt  skew
# Sales    229.86   54.49 12.96 305.31 12.97
# Profit    28.66    8.67  0.00 397.19  7.56
# Quantity   3.79    3.00  3.00   1.99  1.28
# Discount   0.16    0.20  0.00   2.41  1.68

# %%
df[num_cols].var()
# Out:
# Sales      388,434.46
# Profit      54,877.80
# Quantity         4.95
# Discount         0.04
# dtype: float64

# %%
df[num_cols].describe().T # table format change
# Out:
#             count   mean    std       min   25%   50%    75%       max
# Sales    9,994.00 229.86 623.25      0.44 17.28 54.49 209.94 22,638.48
# Profit   9,994.00  28.66 234.26 -6,599.98  1.73  8.67  29.36  8,399.98
# Quantity 9,994.00   3.79   2.23      1.00  2.00  3.00   5.00     14.00
# Discount 9,994.00   0.16   0.21      0.00  0.00  0.20   0.20      0.80

# %% [markdown]
# ### **Observations**
#
# - Sales and Profit have a noticeable difference between their mean and median, suggesting that a few high-value transactions increase the average.
# - Quantity and Discount have mean and median values that are quite close, indicating a more balanced distribution.
# - **Sales** is the most positively skewed feature, followed by **Profit**, while **Quantity** and **Discount** are comparatively less skewed.
# - **Sales** and **Profit** contain several high-value outliers, whereas **Quantity** and **Discount** have relatively fewer extreme values.
# - **Sales** and **Profit** show a much wider range of values compared to **Quantity** and **Discount**, indicating greater variation.
# - No major anomalies or invalid values were found in the numerical columns.

# %% [markdown]
# ### **Part B – Categorical Features**

# %%
cat_cols=["Ship Mode","Segment","Region","Category","Sub-Category"]
for col in cat_cols:
  display(Markdown(f"###**{col}**"))
  print(df[col].value_counts())
  display((df[col].value_counts(normalize=True)*100).round(2))
# Out:
# ###**Ship Mode**
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64
# Ship Mode
# Standard Class   59.72
# Second Class     19.46
# First Class      15.39
# Same Day          5.43
# Name: proportion, dtype: float64
# ###**Segment**
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64
# Segment
# Consumer      51.94
# Corporate     30.22
# Home Office   17.84
# Name: proportion, dtype: float64
# ###**Region**
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64
# Region
# West      32.05
# East      28.50
# Central   23.24
# South     16.21
# Name: proportion, dtype: float64
# ###**Category**
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64
# Category
# Office Supplies   60.30
# Furniture         21.22
# ...

# %%
df[cat_cols].nunique()
# Out:
# Ship Mode        4
# Segment          3
# Region           4
# Category         3
# Sub-Category    17
# dtype: int64

# %% [markdown]
# ### **Observations**
#
# - **Standard Class** is the most commonly used shipping mode (≈60%), while **Same Day** is the least used (≈5%).
# - The **Consumer segment** accounts for the highest number of transactions (≈52%), followed by **Corporate** and **Home Office**.
# - The **West region** has the highest number of transactions, although the distribution across all four regions is fairly balanced.
# - **Office Supplies** is the most purchased category, contributing around **60%** of all transactions.
# - **Binders** are the most frequently purchased sub-category, whereas **Copiers** have the fewest transactions.
# - The categorical columns contain consistent values with no obvious inconsistencies.

# %% [markdown]
# ## **Phase 4 – Bivariate Analysis**

# %%
df[num_cols].corr()
# Out:
#           Sales  Profit  Quantity  Discount
# Sales      1.00    0.48      0.20     -0.03
# Profit     0.48    1.00      0.07     -0.22
# Quantity   0.20    0.07      1.00      0.01
# Discount  -0.03   -0.22      0.01      1.00

# %%
for x in cat_cols:
  print(f"\n{'='*50}")
  display(Markdown(f"###**{x}**"))
  grouped=grouped = df.groupby(x).agg({
    "Sales": ["sum", "mean"],
    "Profit": ["sum", "mean"],
    "Quantity": "sum",
    "Discount": "mean"
})
  grouped.columns=["_".join(map(str,col))for col in grouped.columns]
  grouped=grouped.sort_values("Sales_sum",ascending=False)
  display(grouped)
# Out:
# ...
# ###**Ship Mode**
#                   Sales_sum  Sales_mean  Profit_sum  Profit_mean  \
# Ship Mode
# Standard Class 1,358,215.74      227.58  164,088.79        27.49
# Second Class     459,193.57      236.09   57,446.64        29.54
# First Class      351,428.42      228.50   48,969.84        31.84
# Same Day         128,363.12      236.40   15,891.76        29.27
#
#                 Quantity_sum  Discount_mean
# Ship Mode
# Standard Class         22797           0.16
# Second Class            7423           0.14
# First Class             5693           0.16
# Same Day                1960           0.15
# ...
# ###**Segment**
#                Sales_sum  Sales_mean  Profit_sum  Profit_mean  Quantity_sum  \
# Segment
# Consumer    1,161,401.34      223.73  134,119.21        25.84         19521
# Corporate     706,146.37      233.82   91,979.13        30.46         11608
# Home Office   429,653.15      240.97   60,298.68        33.82          6744
#
#              Discount_mean
# Segment
# ...

# %%
piv_reg=pd.pivot_table(df,index="Region",values=["Sales","Profit","Discount"],columns="Category",aggfunc="mean",sort=False)
piv_reg.columns=("_".join(map(str,col)) for col in piv_reg.columns)
piv_reg.T
# Out:
# Region                    South   West  Central   East
# Sales_Furniture          353.31 357.30   340.53 346.57
# Sales_Office Supplies    126.28 116.42   117.46 120.04
# Sales_Technology         507.75 420.69   405.75 495.28
# Profit_Furniture          20.40  16.27    -5.97   5.07
# Profit_Office Supplies    20.09  27.73     6.24  23.96
# Profit_Technology         68.23  73.96    80.23  88.71
# Discount_Furniture         0.12   0.13     0.30   0.15
# Discount_Office Supplies   0.17   0.09     0.25   0.14
# Discount_Technology        0.11   0.13     0.13   0.14

# %% [markdown]
# ### **Observations**
#
# - Sales and Profit show a moderate positive correlation (**r = 0.48**), while Discount has a weak negative correlation with Profit (**r = -0.22**), indicating that higher discounts tend to reduce profitability.
# - **Standard Class** contributes the highest total sales, whereas **First Class** generates the highest average profit per transaction.
# - The **Consumer** segment contributes the highest total sales, while the **Home Office** segment records the highest average profit per order.
# - The **West** region generates the highest total sales and profit, whereas the **Central** region has the lowest average profit and the highest average discount.
# - **Technology** is the best-performing category in terms of average sales and profit, while **Furniture** generates high sales but comparatively lower profit.
# - **Copiers** generate the highest average sales and profit per transaction despite having a low sales volume. In contrast, **Tables, Bookcases, and Supplies** are the only loss-making sub-categories.
# - **Furniture** in the **Central** region records a negative average profit along with the highest average discount, suggesting that heavy discounting may be reducing profitability.

# %% [markdown]
# ## **Phase 5 – Business Insights**

# %% [markdown]
# #### **A. Product Analysis**

# %%
df.groupby("Product Name")["Sales"].agg("sum").sort_values(ascending=False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                         61,599.82
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind   27,453.38
# Cisco TelePresence System EX90 Videoconferencing Unit                         22,638.48
# HON 5400 Series Task Chairs for Big and Tall                                  21,870.58
# GBC DocuBind TL300 Electric Binding System                                    19,823.48
# GBC Ibimaster 500 Manual ProClick Binding System                              19,024.50
# Hewlett Packard LaserJet 3310 Copier                                          18,839.69
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                     18,374.90
# GBC DocuBind P400 Electric Binding System                                     17,965.07
# High Speed Automatic Electric Letter Opener                                   17,030.31
# Name: Sales, dtype: float64

# %%
df.groupby(["Product Name","Category"])["Profit"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name                                                                 Category
# Canon imageCLASS 2200 Advanced Copier                                        Technology        25,199.93
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind  Office Supplies    7,753.04
# Hewlett Packard LaserJet 3310 Copier                                         Technology         6,983.88
# Canon PC1060 Personal Laser Copier                                           Technology         4,570.93
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                    Technology         4,094.98
# Ativa V4110MDD Micro-Cut Shredder                                            Technology         3,772.95
# 3D Systems Cube Printer, 2nd Generation, Magenta                             Technology         3,717.97
# Plantronics Savi W720 Multi-Device Wireless Headset System                   Technology         3,696.28
# ...

# %%
df.groupby(["Product Name","Category"])["Profit"].sum().sort_values(ascending=True).head(10)
# Out:
# Product Name                                                       Category
# Cubify CubeX 3D Printer Double Head Print                          Technology        -8,879.97
# Lexmark MX611dhe Monochrome Laser Printer                          Technology        -4,589.97
# Cubify CubeX 3D Printer Triple Head Print                          Technology        -3,839.99
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases           Furniture         -2,876.12
# Bush Advantage Collection Racetrack Conference Table               Furniture         -1,934.40
# GBC DocuBind P400 Electric Binding System                          Office Supplies   -1,878.17
# Cisco TelePresence System EX90 Videoconferencing Unit              Technology        -1,811.08
# Martin Yale Chadless Opener Electric Letter Opener                 Office Supplies   -1,299.18
# Balt Solid Wood Round Tables                                       Furniture         -1,201.06
# ...

# %%
df.groupby(["Sub-Category","Category"])["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Sub-Category  Category
# Phones        Technology        330,007.05
# Chairs        Furniture         328,449.10
# Storage       Office Supplies   223,843.61
# Tables        Furniture         206,965.53
# Binders       Office Supplies   203,412.73
# Machines      Technology        189,238.63
# Accessories   Technology        167,380.32
# Copiers       Technology        149,528.03
# Bookcases     Furniture         114,880.00
# Appliances    Office Supplies   107,532.16
# Name: Sales, dtype: float64

# %%
df.groupby(["Sub-Category","Category"])["Profit"].sum().sort_values(ascending=True).head(10)
# Out:
# Sub-Category  Category
# Tables        Furniture         -17,725.48
# Bookcases     Furniture          -3,472.56
# Supplies      Office Supplies    -1,189.10
# Fasteners     Office Supplies       949.52
# Machines      Technology          3,384.76
# Labels        Office Supplies     5,546.25
# Art           Office Supplies     6,527.79
# Envelopes     Office Supplies     6,964.18
# Furnishings   Furniture          13,059.14
# Appliances    Office Supplies    18,138.01
# Name: Profit, dtype: float64

# %%
df.groupby("Order ID").agg({
    "Sales":"sum",
    "Profit":"sum"
}).describe()
# Out:
#           Sales    Profit
# count  5,009.00  5,009.00
# mean     458.61     57.18
# std      954.73    344.94
# min        0.56 -6,892.37
# 25%       37.63      2.05
# 50%      151.96     16.28
# 75%      512.06     68.69
# max   23,661.23  8,762.39

# %% [markdown]
# #### **B. Customer Analysis**

# %%
df.groupby(["Customer ID","Customer Name"])["Sales"].sum().nlargest(10)
# Out:
# Customer ID  Customer Name
# SM-20320     Sean Miller          25,043.05
# TC-20980     Tamara Chand         19,052.22
# RB-19360     Raymond Buch         15,117.34
# TA-21385     Tom Ashbrook         14,595.62
# AB-10105     Adrian Barton        14,473.57
# KL-16645     Ken Lonsdale         14,175.23
# SC-20095     Sanjit Chand         14,142.33
# HL-15040     Hunter Lopez         12,873.30
# SE-20110     Sanjit Engle         12,209.44
# CC-12370     Christopher Conant   12,129.07
# Name: Sales, dtype: float64

# %%
df.groupby(["Customer ID","Customer Name"])["Profit"].sum().nlargest(10)
# Out:
# Customer ID  Customer Name
# TC-20980     Tamara Chand           8,981.32
# RB-19360     Raymond Buch           6,976.10
# SC-20095     Sanjit Chand           5,757.41
# HL-15040     Hunter Lopez           5,622.43
# AB-10105     Adrian Barton          5,444.81
# TA-21385     Tom Ashbrook           4,703.79
# CM-12385     Christopher Martinez   3,899.89
# KD-16495     Keith Dawkins          3,038.63
# AR-10540     Andy Reiter            2,884.62
# DR-12940     Daniel Raglin          2,869.08
# Name: Profit, dtype: float64

# %%
df.groupby("Customer Name")["Order ID"].nunique().nlargest(10)
# Out:
# Customer Name
# Emily Phan             17
# Chloris Kastensmidt    13
# Erin Ashbrook          13
# Joel Eaton             13
# Noel Staavos           13
# Patrick Gardner        13
# Sally Hughsby          13
# Zuschuss Carroll       13
# Anna Häberlin          12
# Bart Pistole           12
# Name: Order ID, dtype: int64

# %%
seg_an=df.groupby("Segment")[["Sales","Profit"]].agg(["sum","mean"])
seg_an.columns=("_".join(map(str,col)) for col in seg_an.columns)
seg_an
# Out:
#                Sales_sum  Sales_mean  Profit_sum  Profit_mean
# Segment
# Consumer    1,161,401.34      223.73  134,119.21        25.84
# Corporate     706,146.37      233.82   91,979.13        30.46
# Home Office   429,653.15      240.97   60,298.68        33.82

# %% [markdown]
# #### **C. Regional Analysis**

# %%
df.groupby("State")["Sales"].sum().nlargest(10)
# Out:
# State
# California     457,687.63
# New York       310,876.27
# Texas          170,188.05
# Washington     138,641.27
# Pennsylvania   116,511.91
# Florida         89,473.71
# Illinois        80,166.10
# Ohio            78,258.14
# Michigan        76,269.61
# Virginia        70,636.72
# Name: Sales, dtype: float64

# %%
df.groupby("State")["Profit"].sum().nlargest(10)
# Out:
# State
# California   76,381.39
# New York     74,038.55
# Washington   33,402.65
# Michigan     24,463.19
# Virginia     18,597.95
# Indiana      18,382.94
# Georgia      16,250.04
# Kentucky     11,199.70
# Minnesota    10,823.19
# Delaware      9,977.37
# Name: Profit, dtype: float64

# %%
df.groupby("State")["Profit"].sum().nsmallest(10)
# Out:
# State
# Texas            -25,729.36
# Ohio             -16,971.38
# Pennsylvania     -15,559.96
# Illinois         -12,607.89
# North Carolina    -7,490.91
# Colorado          -6,527.86
# Tennessee         -5,341.69
# Arizona           -3,427.92
# Florida           -3,399.30
# Oregon            -1,190.47
# Name: Profit, dtype: float64

# %%
df.groupby("Region")[["Sales","Profit"]].sum()
# Out:
#              Sales     Profit
# Region
# Central 501,239.89  39,706.36
# East    678,781.24  91,522.78
# South   391,721.91  46,749.43
# West    725,457.82 108,418.45

# %% [markdown]
# #### **D. Time Analysis**

# %%
df["Order Date"].dt.year.unique()
# Out:
# array([2016, 2015, 2014, 2017], dtype=int32)

# %%
df.groupby([df["Order Date"].dt.to_period("M"),df["Order Date"].dt.month_name()])["Sales"].sum()
# Out:
# Order Date  Order Date
# 2014-01     January       14,236.90
# 2014-02     February       4,519.89
# 2014-03     March         55,691.01
# 2014-04     April         28,295.35
# 2014-05     May           23,648.29
# 2014-06     June          34,595.13
# 2014-07     July          33,946.39
# 2014-08     August        27,909.47
# 2014-09     September     81,777.35
# 2014-10     October       31,453.39
# 2014-11     November      78,628.72
# 2014-12     December      69,545.62
# 2015-01     January       18,174.08
# 2015-02     February      11,951.41
# 2015-03     March         38,726.25
# 2015-04     April         34,195.21
# 2015-05     May           30,131.69
# 2015-06     June          24,797.29
# 2015-07     July          28,765.33
# 2015-08     August        36,898.33
# 2015-09     September     64,595.92
# 2015-10     October       31,404.92
# 2015-11     November      75,972.56
# 2015-12     December      74,919.52
# 2016-01     January       18,542.49
# ...

# %%
df.groupby([df["Order Date"].dt.to_period("M"),df["Order Date"].dt.month_name()])["Profit"].sum()
# Out:
# Order Date  Order Date
# 2014-01     January       2,450.19
# 2014-02     February        862.31
# 2014-03     March           498.73
# 2014-04     April         3,488.84
# 2014-05     May           2,738.71
# 2014-06     June          4,976.52
# 2014-07     July           -841.48
# 2014-08     August        5,318.10
# 2014-09     September     8,328.10
# 2014-10     October       3,448.26
# 2014-11     November      9,292.13
# 2014-12     December      8,983.57
# 2015-01     January      -3,281.01
# 2015-02     February      2,813.85
# 2015-03     March         9,732.10
# 2015-04     April         4,187.50
# 2015-05     May           4,667.87
# 2015-06     June          3,335.56
# 2015-07     July          3,288.65
# 2015-08     August        5,355.81
# 2015-09     September     8,209.16
# 2015-10     October       2,817.37
# 2015-11     November     12,474.79
# 2015-12     December      8,016.97
# 2016-01     January       2,824.82
# 2016-02     February      5,004.58
# ...

# %%
df.groupby([df["Order Date"].dt.to_period("Y"),"Category"])[["Sales","Profit"]].sum()
# Out:
#                                 Sales    Profit
# Order Date Category
# 2014       Furniture       157,192.85  5,457.73
#            Office Supplies 151,776.41 22,593.42
#            Technology      175,278.23 21,492.83
# 2015       Furniture       170,518.24  3,015.20
#            Office Supplies 137,233.46 25,099.53
#            Technology      162,780.81 33,503.87
# 2016       Furniture       198,901.44  6,959.95
#            Office Supplies 183,939.98 35,061.23
#            Technology      226,364.18 39,773.99
# 2017       Furniture       215,387.27  3,018.39
#            Office Supplies 246,097.17 39,736.62
#            Technology      271,730.81 50,684.26

# %%
monthly_discount=df.groupby([df["Order Date"].dt.to_period("M"),df["Order Date"].dt.month_name()])[["Quantity","Discount"]].agg({"Quantity":"sum","Discount":"mean"})
display(monthly_discount[monthly_discount["Quantity"]<300])
# Out:
#                        Quantity  Discount
# Order Date Order Date
# 2014-01    January          284      0.13
# 2014-02    February         159      0.18
# 2015-01    January          236      0.18
# 2015-02    February         239      0.13

# %% [markdown]
# #### **E. Discount Analysis**

# %%
df.groupby("Discount")[["Sales","Profit"]].mean()
# Out:
#           Sales  Profit
# Discount
# 0.00     226.74   66.90
# 0.10     578.40   96.06
# 0.15     529.97   27.29
# 0.20     209.08   24.70
# 0.30     454.74  -45.68
# 0.32     536.79  -88.56
# 0.40     565.13 -111.93
# 0.45     498.63 -226.65
# 0.50     892.71 -310.70
# 0.60      48.15  -43.08
# 0.70      97.18  -95.87
# 0.80      56.55 -101.80

# %%
df.groupby(["Category","Sub-Category"])["Discount"].mean().sort_values(ascending=False)
# Out:
# Category         Sub-Category
# Office Supplies  Binders        0.37
# Technology       Machines       0.31
# Furniture        Tables         0.26
#                  Bookcases      0.21
#                  Chairs         0.17
# Office Supplies  Appliances     0.17
# Technology       Copiers        0.16
#                  Phones         0.15
# Furniture        Furnishings    0.14
# Office Supplies  Fasteners      0.08
#                  Envelopes      0.08
# Technology       Accessories    0.08
# Office Supplies  Supplies       0.08
#                  Paper          0.07
#                  Art            0.07
#                  Storage        0.07
#                  Labels         0.07
# Name: Discount, dtype: float64

# %% [markdown]
# ### **Observations**
#
# - **Canon imageCLASS 2200 Advanced Copier** is both the highest-selling and the most profitable product, while most of the top profitable products belong to the **Technology** category.
# - Despite generating high sales, a few products—particularly **Cubify CubeX 3D Printers** and **Cisco TelePresence System EX90**—record substantial losses, showing that high revenue does not always result in high profit.
# - **Phones** and **Chairs** generate the highest sales among all sub-categories, whereas **Tables**, **Bookcases**, and **Supplies** are the major loss-making sub-categories.
# - **Sean Miller** is the highest-spending customer, while **Tamara Chand** generates the highest overall profit. The **Home Office** segment records the highest average sales and profit per order.
# - **California** and **New York** are the strongest-performing states in both sales and profit, whereas **Texas** records the highest overall loss despite being among the top-selling states.
# - Sales and profit generally increase over the years, indicating steady business growth between **2014** and **2017**.
# - Higher discount levels (especially **30% and above**) are associated with negative average profits. **Binders**, **Machines**, and **Tables** receive the highest average discounts, suggesting that aggressive discounting may be reducing profitability.

# %% [markdown]
# ## **Phase 6: Data Visualization (Matplotlib)**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 6.1 Monthly Sales Trend

# %%
monthly_sales= df.groupby(df["Order Date"].dt.to_period("M"))["Sales"].sum()
monthly_sales.index=monthly_sales.index.to_timestamp().strftime("%b-%Y") #converting period to timestamp(datetime)

plt.figure(figsize=(12,4))
plt.plot(monthly_sales.index,monthly_sales.values, marker="o",color="green",mec="black",mew=1.5,mfc="white")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(monthly_sales.index[::2], rotation=45) #to skip alternative month name for space
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Observation**
# - Sales fluctuate considerably across the **2014–2017** period, indicating noticeable seasonal variation.
#
# - The highest monthly sales occur in late 2017, where sales exceed **115,000**, making it the strongest-performing month in the dataset.
#
# - Sales repeatedly increase during the **September–November period**, suggesting a recurring year-end sales surge.
#
# - The overall trend from 2014 to 2017 is **upward**, with both peak sales and average monthly sales increasing over time.

# %% [markdown]
# ### 6.2 Monthly Sales and Profit Comparison

# %%
monthly_sp=df.groupby(df["Order Date"].dt.to_period("M"))[["Sales","Profit"]].sum()
monthly_sp.index=monthly_sp.index.to_timestamp().strftime("%b-%Y") #converting period to timestamp(datetime)

plt.figure(figsize=(12,4))
plt.plot(monthly_sp.index,monthly_sp["Sales"] ,label="Sales", marker="o",linewidth=2, color="blue",mec="black",mew=1.5,mfc="white")
plt.plot(monthly_sp.index,monthly_sp["Profit"],label="Profit", marker="o",linewidth=2, color="green",mec="black",mew=1.5,mfc="white")
plt.title("Monthly Sales and Profit Comparison")
plt.xlabel("Month")
plt.ylabel("Amount")
plt.xticks(monthly_sp.index[::2],rotation=45) #to skip alternative month name for space
plt.legend(loc="upper left")
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Observation**
# - Sales and Profit generally move in the **same direction**, showing that higher sales usually contribute to higher profit.
#
# - Profit values are much **smaller in magnitude** than sales, indicating that revenue growth does not translate proportionally into profit growth.
#
# - Some months show **strong sales but relatively lower profit**, suggesting the possible impact of discounts, shipping costs, or lower-margin products.
#
# - The strongest combined sales and profit performance occurs during the **second half of 2017**.

# %% [markdown]
# ### 6.3 Sales by Category

# %%
cat_sales=df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
plt.figure(figsize=(6,4))
plt.bar(cat_sales.index,cat_sales,color="orange",edgecolor="black")
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation**
# - **Technology** is the highest revenue-generating category, contributing approximately **830K+** in sales.
#
# - **Furniture** and **Office Supplies** generate similar sales volumes, both remaining below Technology.
#
# - The business appears to rely heavily on **Technology products for revenue generation**, while the other two categories provide substantial but comparatively lower contributions.

# %% [markdown]
# ### 6.4 Top 10 Sub-Categories by Sales

# %%
subcat_sales=df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,5))
plt.barh(subcat_sales.index,subcat_sales.values,color="purple",edgecolor="black",height=0.6)
plt.title("Sales by Sub-Category")
plt.xlabel("Sales")
plt.ylabel("Sub-Category")
plt.grid(axis="x")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation**
# - Phones and Chairs are the two strongest-performing sub-categories, each generating roughly 330K in sales.
#
# - Technology-related products such as **Phones, Copiers, Accessories, and Machines** appear frequently among the top performers.
#
# - **Storage, Tables, and Binders** also contribute significantly, showing that both **Technology and Furniture products drive a large share of total revenue.**
#
# - Sales are concentrated in a relatively small number of sub-categories rather than being evenly distributed across all product types.

# %% [markdown]
# ### 6.5 Sales Distribution

# %%
plt.figure(figsize=(8,4))
plt.hist(df["Sales"],bins=30,edgecolor="black")
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation**
# - The histogram is **heavily right-skewed**, with most orders concentrated at **low sales values**.
#
# - The majority of transactions appear to fall below **1,000**, while only a small number of orders exceed **5,000**.
#
# - The long right tail indicates the presence of **high-value outlier transactions** that significantly influence the overall sales distribution.
#
# - The business processes **many small orders and relatively few very large orders**.

# %% [markdown]
# ### 6.6 Sales vs Profit Relationship

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Sales"],
            df["Profit"],
            s=25,
            alpha=0.5,
            color="steelblue")

# trend line
m, b = np.polyfit(df["Sales"], df["Profit"], 1) # y=mx+b
plt.plot(df["Sales"],
         m * df["Sales"] + b,
         color="red",
         linewidth=2)

plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")

plt.xlim(0, 10000) #x axis limit
plt.ylim(-4000, 6000) #y axis limit

plt.grid(True, alpha=0.3) #alpha is transparency(0-1[trans-opa])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation**
# - The scatter plot shows a **moderate positive relationship** between Sales and Profit, supported by the upward-sloping trend line.
#
# - Most transactions are concentrated in the **0–3,000 sales range** with profits clustered near zero.
#
# - Several orders with sales between **1,000 and 4,000** generate **negative profit**, indicating that higher sales do not always guarantee profitability.
#
# - A few higher-sales transactions produce **substantially higher profits**, but the spread of points shows considerable variability in profit outcomes across similar sales levels.

# %% [markdown]
# ### 6.7 Regional Sales Comparison

# %%
reg_sales=df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
plt.figure(figsize=(8,4))
plt.bar(reg_sales.index,reg_sales,color="pink",edgecolor="black")
plt.title("Regional Sales Comparison")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation**
# - The **West** region generates the highest sales, exceeding **720K**.
#
# - The **East** region follows closely behind, while the **Central** region contributes a moderate share of revenue.
#
# - The **South** region records the lowest sales performance among all regions.
#
# - The company’s strongest revenue base is concentrated in the **West and East regions**, which together account for the majority of total sales.

# %% [markdown]
# ### 6.8 Segment Distibution

# %%
seg_count=df["Segment"].value_counts() #frequncy of each unique segment
plt.figure(figsize=(6,4))
plt.pie(seg_count.values,labels=seg_count.index,autopct="%1.1f%%",startangle=90)
plt.title("Customer Segment Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation**
# - The **Consumer** segment is the dominant customer group, representing **51.9%** of all customers.
#
# - The **Corporate** segment contributes **30.2%**, forming a substantial secondary customer base.
#
# - **Home Office** customers account for **17.8%**, making it the smallest segment.
#
# - The business is therefore **primarily consumer-driven**, with more than half of its customer base coming from individual consumers rather than corporate or home-office buyers.

# %% [markdown]
# ## **Phase 7: Data Visualization (Seaborn)**

# %%
import seaborn as sns
sns.set_theme(style="whitegrid", palette="Set2") #setting the style and color palette

# %% [markdown]
# ### 7.1 Sales Distribution (Histogram)

# %%
plt.figure(figsize=(16,5))
sns.histplot(data=df,x="Sales",kde=True,bins=100,color="orange",edgecolor="black",alpha=0.7,linewidth=1)
plt.title("Sales Distribution")
plt.xticks(range(0,20000,1000))
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.grid(axis="y",alpha=0.4)
plt.show()

# %% [markdown]
# ### **Observation**
#
# * The majority of orders are concentrated in the **low sales range (0–800)**.
# * The distribution is **strongly right-skewed**, meaning most transactions are small-value orders.
# * A few very large sales values extend the tail toward the right side of the distribution.
# * This suggests the business is driven primarily by **many small orders**, while high-value transactions occur relatively rarely.

# %% [markdown]
# ### **Observation**
#
# * The majority of orders are concentrated in the **low sales range (0–800)**.
# * The distribution is **strongly right-skewed**, meaning most transactions are small-value orders.
# * A few very large sales values extend the tail toward the right side of the distribution.
# * This suggests the business is driven primarily by **many small orders**, while high-value transactions occur relatively rarely.

# %% [markdown]
# ### 7.2 Profit Distribution by Category (Box Plot)

# %%
plt.figure(figsize=(18,5))  # one figure for all 3 plots

# Original boxplot
plt.subplot(1,3,1)
sns.boxplot(data=df,
            x="Category",
            y="Profit",
            palette="Set2")
plt.title("Original")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.yticks(range(-5000, 7001, 1000)) #set min max range
plt.grid(axis="y", alpha=0.4)

# Zoomed boxplot
plt.subplot(1,3,2)
sns.boxplot(data=df,
            x="Category",
            y="Profit",
            palette="Set2")
plt.ylim(-500, 1000)  # zoom into main distribution
plt.title("Zoomed")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.grid(axis="y", alpha=0.4)

# Without outliers
plt.subplot(1,3,3)
sns.boxplot(data=df,
            x="Category",
            y="Profit",
            palette="Set2",
            showfliers=False)  # hide outlier points
plt.title("Without Outliers")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.grid(axis="y", alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_39252/1867098308.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,
# /tmp/ipykernel_39252/1867098308.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,
# /tmp/ipykernel_39252/1867098308.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,

# %% [markdown]
# ### **Observation**
#
# * **Technology has the highest median profit** among the three categories.
# * It also shows the **largest interquartile range (IQR)**, indicating greater variability in profits.
# * Office Supplies has the narrowest spread, suggesting more stable and consistent profits.
# * Furniture contains several negative-profit observations, indicating occasional loss-making orders.
# * Technology also contains the most extreme positive and negative profit outliers.

# %% [markdown]
# ### 7.3 Sales vs Profit Relationship (Regression Plot)

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=df,x="Sales",y="Profit",
            scatter_kws={"s":100,
                         "color":"purple",
                         "edgecolor":"black",
                         "marker":"o",
                         "alpha":0.4},
            line_kws={"color":"green",
                      "linewidth":2,
                      })
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.grid(True,alpha=0.5)
plt.show()

# %% [markdown]
# ### **Observation**
#
# * The regression line slopes upward, indicating a **moderate positive relationship between Sales and Profit**.
# * Lower sales values remain relatively close to the regression line, while higher sales values show greater dispersion.
# * Some high-sales orders generate significant losses, suggesting that **higher sales do not always guarantee higher profitability**.
# * The wide confidence interval indicates that the relationship is not strongly linear.

# %% [markdown]
# ### 7.4 Correlation Heatmap

# %%
corr_mat=df[["Sales","Profit","Discount","Quantity"]].corr()
plt.figure(figsize=(7,5))
sns.heatmap(corr_mat,annot=True,cmap="coolwarm",fmt=".2f",linewidth=1,linecolor="white")
plt.title("Heatmap of Correlation")
plt.show()

# %% [markdown]
# ### **Observation**
#
# * **Sales and Profit show a moderate positive correlation (0.48)**, meaning higher sales generally tend to be associated with higher profits.
# * **Discount and Profit show a moderate negative correlation (-0.22)**, suggesting that increasing discounts tends to reduce profitability.
# * Sales and Quantity show only a weak positive relationship (0.20).
# * The remaining variable pairs have correlations close to zero, indicating very weak relationships.
# * Overall, **Profit appears to be influenced by multiple factors, and Sales alone is not a strong predictor of profitability**.
